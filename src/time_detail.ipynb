# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# paths for output files
root_path = r'..\data'
paths = {
    'CXR_AI' : root_path + r'\\AI\output\Dataset_CXR_AI.csv',
    'CXR_Normal' : root_path + r'\\Normal\output\Dataset_CXR_Normal.csv',
    'MURA_AI' : root_path + r'\\AI\output\Dataset_MURA_AI.csv',
    'MURA_Normal' : root_path + r'\\Normal\output\Dataset_MURA_Normal.csv',
    'Mammography_AI' : root_path + r'\\AI\output\Dataset_Mammography_AI.csv',
    'Mammography_Normal' : root_path + r'\\Normal\output\Dataset_Mammography_Normal.csv',
    'Pneumothorax_AI' : root_path + r'\\AI\output\Dataset_Pneumothorax_AI.csv',
    'Pneumothorax_Normal' : root_path + r'\\Normal\output\Dataset_Pneumothorax_Normal.csv'
    }

# read files
cxr_ai = pd.read_csv(paths['CXR_AI'])
cxr_normal = pd.read_csv(paths['CXR_Normal'])
mura_ai = pd.read_csv(paths['MURA_AI'])
mura_normal = pd.read_csv(paths['MURA_Normal'])
mammography_ai = pd.read_csv(paths['Mammography_AI'])
mammography_normal = pd.read_csv(paths['Mammography_Normal'])
pneumothorax_ai = pd.read_csv(paths['Pneumothorax_AI'])
pneumothorax_normal = pd.read_csv(paths['Pneumothorax_Normal'])

plt.figure(figsize=(12, 16))
# cxr time extract
# cxr_ai = cxr_ai.sort_values(['updatedById', 'end_time'])
# cxr_ai['end_time'] = pd.to_datetime(cxr_ai['end_time'])
# cxr_ai['time_taken'] = cxr_ai.groupby('updatedById')['end_time'].diff()
# cxr_ai['time_taken_secs'] = cxr_ai['time_taken'].dt.seconds
# cxr_ai.to_csv(paths['CXR_AI'], index = False)
plt.subplot(4,2,1)
cxr_ai['time_taken_secs'].plot(kind = 'box')
plt.title("CXR - AI Assisted - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)

# cxr_normal = cxr_normal.sort_values(['updatedById', 'end_time'])
# cxr_normal['end_time'] = pd.to_datetime(cxr_normal['end_time'])
# cxr_normal['time_taken'] = cxr_normal.groupby('updatedById')['end_time'].diff()
# cxr_normal['time_taken_secs'] = cxr_normal['time_taken'].dt.seconds
# cxr_normal.to_csv(paths['CXR_Normal'], index = False)
plt.subplot(4,2,2)
cxr_normal['time_taken_secs'].plot(kind = 'box')
plt.title("CXR - Non AI - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)


# mura time extract
# mura_ai = mura_ai.sort_values(['updatedById', 'updatedAt'])
# mura_ai['updatedAt'] = pd.to_datetime(mura_ai['updatedAt'])
# mura_ai['time_taken'] = mura_ai.groupby('updatedById')['updatedAt'].diff()
# mura_ai['time_taken_secs'] = mura_ai['time_taken'].dt.seconds
# mura_ai.to_csv(paths['MURA_AI'], index = False)
plt.subplot(4,2,3)
mura_ai['time_taken_secs'].plot(kind = 'box')
plt.title("MURA - AI Assisted - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)


# mura_normal = mura_normal.sort_values(['updatedById', 'end_time'])
# mura_normal['end_time'] = pd.to_datetime(mura_normal['end_time'])
# mura_normal['time_taken'] = mura_normal.groupby('updatedById')['end_time'].diff()
# mura_normal['time_taken_secs'] = mura_normal['time_taken'].dt.seconds
# mura_normal.to_csv(paths['MURA_Normal'], index = False)
plt.subplot(4,2,4)
mura_normal['time_taken_secs'].plot(kind = 'box')
plt.title("MURA - Non AI - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)


# mammo time extract
# mammography_ai = mammography_ai.sort_values(['updatedById', 'updatedAt'])
# mammography_ai['updatedAt'] = pd.to_datetime(mammography_ai['updatedAt'])
# mammography_ai['time_taken'] = mammography_ai.groupby('updatedById')['updatedAt'].diff()
# mammography_ai['time_taken_secs'] = mammography_ai['time_taken'].dt.seconds
# mammography_ai.to_csv(paths['Mammography_AI'], index = False)
plt.subplot(4,2,5)
mammography_ai['time_taken_secs'].plot(kind = 'box')
plt.title("Mammo - AI Assisted - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)


# mammography_normal = mammography_normal.sort_values(['updatedById', 'updatedAt'])
# mammography_normal['updatedAt'] = pd.to_datetime(mammography_normal['updatedAt'])
# mammography_normal['time_taken'] = mammography_normal.groupby('updatedById')['updatedAt'].diff()
# mammography_normal['time_taken_secs'] = mammography_normal['time_taken'].dt.seconds
# mammography_normal.to_csv(paths['Mammography_Normal'], index = False)
plt.subplot(4,2,6)
mammography_normal['time_taken_secs'].plot(kind = 'box')
plt.title("Mammo - Non AI - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)

# pneumothorax time extract
# pneumothorax_ai = pneumothorax_ai.sort_values(['updatedById', 'updatedAt'])
# pneumothorax_ai['updatedAt'] = pd.to_datetime(pneumothorax_ai['updatedAt'])
# pneumothorax_ai['time_taken'] = pneumothorax_ai.groupby('updatedById')['updatedAt'].diff()
# pneumothorax_ai['time_taken_secs'] = pneumothorax_ai['time_taken'].dt.seconds
# pneumothorax_ai.to_csv(paths['Pneumothorax_AI'], index = False)
plt.subplot(4,2,7)
pneumothorax_ai['time_taken_secs'].plot(kind = 'box')
plt.title("Pneumothorax - AI Assisted - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)

# pneumothorax_normal = pneumothorax_normal.sort_values(['updatedById', 'updatedAt'])
# pneumothorax_normal['updatedAt'] = pd.to_datetime(pneumothorax_normal['updatedAt'])
# pneumothorax_normal['time_taken'] = pneumothorax_normal.groupby('updatedById')['updatedAt'].diff()
# pneumothorax_normal['time_taken_secs'] = pneumothorax_normal['time_taken'].dt.seconds
# pneumothorax_normal.to_csv(paths['Pneumothorax_Normal'], index = False)
plt.subplot(4,2,8)
pneumothorax_normal['time_taken_secs'].plot(kind = 'box')
plt.title("Pneumothorax - Non AI - Time Taken per Study Distribution")
plt.ylabel("Time in Seconds")
plt.ylim(0,200)

plt.show()

# %% [markdown]
# #### Time Analysis

# %%
### time analysis ###
df = pd.read_csv(r"..\data\time_detail.csv")
df['type'] = df['type'].replace({'Human':'Non-AI', 'Human_AI':'AI Assisted'})
df = df[~df['time_taken_secs'].isna()]
# removing faulty outlier study
df = df[~(df['time_taken_secs'] == 507)]
# Sort DataFrame based on start time
df = df.sort_values(by=['updatedById', 'modality', 'type', 'updatedAt'])

# Generate task_number column
df['task_number'] = df.groupby(['updatedById', 'modality', 'type']).cumcount() + 1
df = df[df['task_number'] <= 15]

### IQR based outlier removal ###
Q1 = df['time_taken_secs'].quantile(0.25)
Q3 = df['time_taken_secs'].quantile(0.75)
IQR = Q3 - Q1
# Defining bounds for the outliers
lower_bound = Q1 - 2 * IQR
upper_bound = Q3 + 2 * IQR
print("lower bound : ", lower_bound, "upper bound : ", upper_bound)
# Filtering the data to remove outliers
df = df[(df['time_taken_secs'] >= lower_bound) & (df['time_taken_secs'] <= upper_bound)]

# boxplot - Human VS Human+AI
plt.figure(figsize=(8, 10))
sns.violinplot(x='type', y='time_taken_secs', data=df[df['time_taken_secs'] < 300], inner=None)
sns.boxplot(x='type', y='time_taken_secs', data=df[df['time_taken_secs'] < 300])
plt.xlabel('Study Type')
plt.ylabel('Time in Seconds')
plt.title('Time Taken for a Study - Non-AI VS AI Assisted')
plt.show()

# boxplot - Human VS Human+AI by Radiologist
plt.figure(figsize=(18, 10))
sns.boxplot(x='updatedById', y='time_taken_secs', data=df[df['time_taken_secs'] < 300])
plt.ylabel('Time')
plt.title('Time Taken For a Study - By User')
plt.show()

# boxplot - Human VS Human+AI by Radiologist and Phase type
plt.figure(figsize=(16, 6))
sns.boxplot(x='updatedById', y='time_taken_secs', hue='type', data=df)
plt.title('Time taken by User and Type')
plt.show()

# boxplot - Human VS Human+AI by Modality and Phase type
# Reduce the figure size
plt.figure(figsize=(9, 6))
# Adjust the box width to make them more compact
sns.boxplot(x='modality', y='time_taken_secs', hue='type', data=df, width=0.5, boxprops=dict(edgecolor=(0, 0, 0, 0)))
# Remove the border lines around the entire figure
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.ylim(0,200)
plt.xlabel('Modality')
plt.ylabel('Time in Seconds')
plt.rcParams.update({'font.size': 16})  # Adjust the font size as needed
plt.show()
# Out:
# lower bound :  -60.0 upper bound :  150.0

# %%
### TIME ANALYSIS ###
df = pd.read_csv(r"..\data\time_detail.csv")
df = df[~df['time_taken_secs'].isna()]

# removing faulty outlier study
df = df[~(df['time_taken_secs'] == 507)]

# filter for first 15 studies only
df = df.sort_values(by=['updatedById', 'modality', 'type', 'updatedAt'])
df['task_number'] = df.groupby(['updatedById', 'modality', 'type']).cumcount() + 1
df = df[df['task_number'] <= 15]

# Sort DataFrame based on start time
df = df.sort_values(by=['updatedById', 'modality', 'type', 'updatedAt'])
df['type'] = df['type'].replace({'Human':'Non-AI', 'Human_AI':'AI Assisted'})

# Generate task_number column
df['task_number'] = df.groupby(['updatedById', 'modality', 'type']).cumcount() + 1

# Loop through users and plot graphs
unique_users = df['updatedById'].unique()
unique_modality = df['modality'].unique()

# %%
# boxplots by modality and study number

for mod in unique_modality:
    df_mod = df[df['modality'] == mod].sort_values(by = 'type')

    plt.figure(figsize=(12, 6))
    
    # Boxplot using seaborn
    sns.boxplot(x='task_number', y='time_taken_secs', hue='type', data=df_mod)
    
    plt.xlabel('Task Number')
    plt.xlim(-1,14)
    plt.ylim(0, 250)
    plt.ylabel('Time Taken (secs)')
    plt.title(f'{mod} Distribution of Time Taken by All Users for Each Task Number')
    plt.legend(title='Task Type')
    plt.tight_layout()
    
    plt.show()

# %%
# overall time taken by study number

plt.figure(figsize=(12, 6))

# Boxplot using seaborn
sns.boxplot(x='task_number', y='time_taken_secs', hue='type', data=df.sort_values(by = 'type'))

plt.xlabel('Task Number')
plt.xlim(-1,14)
plt.ylim(0, 250)
plt.ylabel('Time Taken (secs)')
plt.title(f'Overall Distribution of Time Taken by All Users for Each Task Number')
plt.legend(title='Task Type')
plt.tight_layout()

plt.show()

# %%
### Numbers ###

df_sub = df[df['task_number'] <= 15]

print("=================================")
print("   By Modality and Phase Type    ")
print("=================================")

grouped_by_type_modality = df_sub.groupby(['type', 'modality'])['time_taken_secs'].agg(['mean', 'std', 'median', lambda x: x.quantile(0.25), lambda x: x.quantile(0.75)])
grouped_by_type_modality.columns = ['mean', 'std', 'median', '1st_quartile', '3rd_quartile']
print(grouped_by_type_modality.reset_index())

print("=================================")
print("        By Phase Type            ")
print("=================================")

grouped_by_type = df_sub.groupby(['type'])['time_taken_secs'].agg(['mean', 'std', 'median', lambda x: x.quantile(0.25), lambda x: x.quantile(0.75)])
grouped_by_type.columns = ['mean', 'std', 'median', '1st_quartile', '3rd_quartile']
print(grouped_by_type)

print("=================================")

# overall_stats = df_sub['time_taken_secs'].agg(['mean', 'std', 'median', lambda x: x.quantile(0.25), lambda x: x.quantile(0.75)])
# overall_stats.index = ['mean', 'std', 'median', '1st_quartile', '3rd_quartile']
# print(overall_stats)
# Out:
# ...
#    By Modality and Phase Type
# ...
#           type      modality       mean        std  median  1st_quartile  \
# 0  AI Assisted           CXR  60.854545  39.324053    49.0          31.0
# 1  AI Assisted          MURA  38.842105  35.168229    28.0          18.0
# 2  AI Assisted   Mammography  39.071006  25.004184    33.0          20.0
# 3  AI Assisted  Pneumothorax  39.006061  32.861776    29.0          19.0
# 4       Non-AI           CXR  71.479532  41.280581    62.0          44.5
# 5       Non-AI          MURA  49.063953  28.662617    46.0          27.0
# 6       Non-AI   Mammography  49.146199  33.080236    41.0          27.5
# 7       Non-AI  Pneumothorax  49.216374  28.728854    43.0          29.0
#
#    3rd_quartile
# 0          84.0
# 1          50.0
# 2          55.0
# 3          46.0
# 4          89.0
# 5          68.0
# 6          62.0
# 7          63.5
# ...
#         By Phase Type
# ...
#                   mean        std  median  1st_quartile  3rd_quartile
# type
# ...
